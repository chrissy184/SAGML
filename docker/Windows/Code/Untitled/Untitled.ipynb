# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('SlotPatronRatingsJan2018Mar2018.csv')

# %%
df.shape
# Out:
# (3729462, 34)

# %%
df.head(10)
# Out:
#    CoinIn  AccountNumber  AssetNumber  CoinOut  AvailableCompPoints  \
# 0    9419      300024840        21681     2850                 6224
# 1    8970      300027357        21767     3970                    0
# 2    4105      300024700        20966     3065                  338
# 3     630      300019112        20158      130                    0
# 4    2380      300024700        20743     2280                  338
# 5    3360      300019485        21015     2360                    0
# 6   13170      300026898        21658    33500                    0
# 7    2050      300024788        20900      183                    0
# 8   49750      300024840        21003    24875                 6224
# 9   34350      300026523        20414    21850                    0
#
#    Slot Denomination TradingDate  HandlePulls  Location  IRSJackpot  \
# 0                1.0   01JAN2018           53       107         969
# 1                1.0   01JAN2018          180      1705           0
# ...

# %%
df.columns
# Out:
# Index(['CoinIn', 'AccountNumber', 'AssetNumber', 'CoinOut',
#        'AvailableCompPoints', 'Slot Denomination', 'TradingDate',
#        'HandlePulls', 'Location', 'IRSJackpot', 'LastMonthYearRated',
#        'PromoCode', 'RatingCode', 'Remarks', 'TimeStopped', 'Status',
#        'TimeStarted', 'TheoCoinIn', 'TheoLoss', 'Zone', 'GameNumber', 'GameID',
#        'GameDenomination', 'GameMaxCoinIn', 'GameProgressiveGroup',
#        'GameOptions', 'GameBaseTheoPayTable', 'TimeCreated', 'DateCreated',
#        'DateModified', 'TimeModified', 'Age', 'Gender', 'MembershipType'],
#       dtype='object')

# %%
df = df[0:10000]

# %%
df1 = df.copy()

# %%
df.set_index(['AccountNumber','TradingDate'], inplace= True)

# %%
df.head()
# Out:
#                            CoinIn  AssetNumber  CoinOut  AvailableCompPoints  \
# AccountNumber TradingDate
# 300024840     01JAN2018      9419        21681     2850                 6224
# 300027357     01JAN2018      8970        21767     3970                    0
# 300024700     01JAN2018      4105        20966     3065                  338
# 300019112     01JAN2018       630        20158      130                    0
# 300024700     01JAN2018      2380        20743     2280                  338
#
#                            Slot Denomination  HandlePulls  Location  \
# AccountNumber TradingDate
# 300024840     01JAN2018                  1.0           53       107
# 300027357     01JAN2018                  1.0          180      1705
# 300024700     01JAN2018                  1.0          159      1511
# 300019112     01JAN2018                  1.0           22      3506
# 300024700     01JAN2018                  1.0           91       705
#
# ...

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                            CoinIn  AssetNumber  CoinOut  AvailableCompPoints  \
# AccountNumber TradingDate
# 300010643     01JAN2018      4784        20326     3080                    0
#               01JAN2018      2400        20845     1400                    0
#               01JAN2018      7240        20651     6250                    0
#               01JAN2018      9484        20327     5415                    0
#               01JAN2018      3450        21112     1150                    0
#
#                            Slot Denomination  HandlePulls  Location  \
# AccountNumber TradingDate
# 300010643     01JAN2018                  1.0          158      3303
#               01JAN2018                  1.0           40       507
#               01JAN2018                  1.0          127      1705
#               01JAN2018                  1.0          148      3304
#               01JAN2018                  2.0           62      2309
#
# ...

# %%
df1.head()
# Out:
#    CoinIn  AccountNumber  AssetNumber  CoinOut  AvailableCompPoints  \
# 0    9419      300024840        21681     2850                 6224
# 1    8970      300027357        21767     3970                    0
# 2    4105      300024700        20966     3065                  338
# 3     630      300019112        20158      130                    0
# 4    2380      300024700        20743     2280                  338
#
#    Slot Denomination TradingDate  HandlePulls  Location  IRSJackpot  \
# 0                1.0   01JAN2018           53       107         969
# 1                1.0   01JAN2018          180      1705           0
# 2                1.0   01JAN2018          159      1511           0
# 3                1.0   01JAN2018           22      3506           0
# 4                1.0   01JAN2018           91       705           0
#
#         ...        GameProgressiveGroup  GameOptions GameBaseTheoPayTable  \
# ...

# %%
new_df1 = df1.groupby(['AccountNumber','TradingDate'], sort= True)

# %%
df.head()
# Out:
#                            CoinIn  AssetNumber  CoinOut  AvailableCompPoints  \
# AccountNumber TradingDate
# 300010643     01JAN2018      4784        20326     3080                    0
#               01JAN2018      2400        20845     1400                    0
#               01JAN2018      7240        20651     6250                    0
#               01JAN2018      9484        20327     5415                    0
#               01JAN2018      3450        21112     1150                    0
#
#                            Slot Denomination  HandlePulls  Location  \
# AccountNumber TradingDate
# 300010643     01JAN2018                  1.0          158      3303
#               01JAN2018                  1.0           40       507
#               01JAN2018                  1.0          127      1705
#               01JAN2018                  1.0          148      3304
#               01JAN2018                  2.0           62      2309
#
# ...

# %%
new_df1.first()
# Out:
#                            CoinIn  AssetNumber  CoinOut  AvailableCompPoints  \
# AccountNumber TradingDate
# 300010643     01JAN2018      4784        20326     3080                    0
# 300010751     01JAN2018      5160        20439     2798                    0
# 300010806     01JAN2018      7480        20897     5640                    0
# 300010986     01JAN2018     79950        20476    68150                    0
# 300011124     01JAN2018      1250        22060      526                  656
# 300012072     01JAN2018      2845        20351     1880                    0
# 300012104     01JAN2018     79728        21446    63128                    0
# 300012171     01JAN2018     15048        21349    17583                    0
# 300013023     01JAN2018      8530        20089     7920                    0
# 300013039     01JAN2018      2640        20090     2240                    0
# 300013166     01JAN2018       525        21676      215                    0
# ...

# %%
new_df1.groups
# Out:
# {(300010643,
#   '01JAN2018'): Int64Index([ 562,  601,  618,  623,  630,  647,  669,  689,  704,  720,  741,
#               770,  790,  801,  817,  825,  830,  864,  903,  934,  966,  977,
#              1045, 1069, 1070],
#             dtype='int64'),
#  (300010751,
#   '01JAN2018'): Int64Index([800, 803, 883, 1032, 1063], dtype='int64'),
#  (300010806,
#   '01JAN2018'): Int64Index([ 558,  570,  600,  626,  645,  670,  681,  700,  710,  748,  753,
#               758,  853,  858,  867,  868,  876,  892,  894,  899,  969,  976,
#              1049, 1051, 1056, 1089],
#             dtype='int64'),
#  (300010986,
#   '01JAN2018'): Int64Index([708, 823, 1085, 1091, 1099, 1104], dtype='int64'),
#  (300011124, '01JAN2018'): Int64Index([944], dtype='int64'),
#  (300012072,
#   '01JAN2018'): Int64Index([ 568,  574,  584,  592,  660,  672,  680,  733,  757,  762,  780,
#               796,  820,  881,  910,  928, 1023, 1075],
#             dtype='int64'),
# ...

# %%
i=0
for name, group in new_df1:
    print(name)
    print(group)
    i=i+1
    if i==5:
        break
# Out:
# (300010643, '01JAN2018')
#       CoinIn  AccountNumber  AssetNumber  CoinOut  AvailableCompPoints  \
# 562     4784      300010643        20326     3080                    0
# 601     2400      300010643        20845     1400                    0
# 618     7240      300010643        20651     6250                    0
# 623     9484      300010643        20327     5415                    0
# 630     3450      300010643        21112     1150                    0
# 647    16830      300010643        21097    14830                    0
# 669     1080      300010643        20658       86                    0
# 689     1760      300010643        20433      330                    0
# 704     3290      300010643        20326     1075                    0
# 720      300      300010643        21106        0                    0
# 741     7216      300010643        20433     2570                    0
# 770     1040      300010643        20774       60                    0
# ...

# %%
df.index.get_level_values(0)
# Out:
# Int64Index([300010643, 300010643, 300010643, 300010643, 300010643, 300010643,
#             300010643, 300010643, 300010643, 300010643,
#             ...
#             300204957, 300204957, 300204957, 300204957, 300204957, 300204957,
#             300204957, 300204957, 300207231, 300207231],
#            dtype='int64', name='AccountNumber', length=10000)

# %%
df3 = pd.DataFrame({'X' : ['A', 'B', 'A', 'B'], 'Y' : [1, 4, 3, 2]})

# %%
df3
# Out:
#    X  Y
# 0  A  1
# 1  B  4
# 2  A  3
# 3  B  2

# %%
df4 = df3.groupby(['X','Y'])

# %%
df4.groups
# Out:
# {('A', 1): Int64Index([0], dtype='int64'),
#  ('A', 3): Int64Index([2], dtype='int64'),
#  ('B', 2): Int64Index([3], dtype='int64'),
#  ('B', 4): Int64Index([1], dtype='int64')}

# %%
for i in df4.groups:
        print(i)
# Out:
# A
# B
